# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya-ayasi/DL-for-Audio/blob/main/MTF_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
import csv
import os
import librosa
import glob
import keras
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q python_speech_features
from python_speech_features import mfcc, logfbank, delta
# Out:
#   Building wheel for python-speech-features (setup.py) ... done

# %%
no_mfcc=13
no_mtf=7
no_features=3*no_mfcc+no_mtf
N_classes=8

# %%
# Initial Parameters
utterance_length = 4600   # maximum-found manually

# %%
folders=os.listdir(path='/content/drive/MyDrive/NEW_MTF')
print(folders)
# Out:
# ['Niram4_train_mtf', 'Niram8_test_mtf', 'Niram4_test_mtf', 'Niram5_test_mtf', 'Niram5_train_mtf', 'Niram6_test_mtf', 'Niram8_train_mtf', 'Niram7_train_mtf', 'Niram6_train_mtf', 'Niram7_test_mtf', 'Niram2_test_mtf', 'Niram2_train_mtf', 'Niram3_train_mtf', 'Niram1_test_mtf', 'Niram3_test_mtf', 'Niram1_train_mtf']

# %%
X=np.zeros((384,46,utterance_length))
XP1=np.zeros((utterance_length,7))

# %%
y=np.zeros((384))
train=np.zeros((384))

# %%
file_no=0

# %%
for i in range(len(folders)):

  files=glob.glob('/content/drive/MyDrive/NEW_MTF/'+folders[i]+'/*')
  res = folders[i].split('_')
  label=res[0].split('m')[1]
  f2='Niram'+label
  label=int(label)-1
  
  if res[1]=='train':
    train1=1
    f1='Niram_train/'
    f3='_train_new/'
  else:
    train1=0
    f1='Niram_test/'
    f3='_test_new/'

  for ff in files:

    print('filename-------',ff)
    f4=ff.split('/')[6]
    audio='/content/drive/MyDrive/'+f1+f2+f3+f4+'.wav'
    print('audio name---',audio)
    print('label--', label,train1)

    df = pandas.read_csv(ff,header=None)
    XP=df.iloc[:,0:no_mtf].values
    XP1[:XP.shape[0],:]=XP
    
    audio_signal,sr =librosa.load(audio,sr=None)

    mfcc_features = librosa.feature.mfcc(y=audio_signal,sr=sr,n_mfcc=no_mfcc,hop_length=int(0.010*sr), n_fft=int(0.030*sr))
    d1_mfcc_feat = delta(mfcc_features, 2)
    d2_mfcc_feat = delta(d1_mfcc_feat, 2)
    
    if mfcc_features.shape[1] > utterance_length:
        mfcc_features1 = mfcc_features[:, 0:utterance_length]
        d1_mfcc_feat1=d1_mfcc_feat[:, 0:utterance_length]
        d2_mfcc_feat1=d2_mfcc_feat[:, 0:utterance_length]
        
    else:
        mfcc_features1 = np.pad(mfcc_features, ((0, 0), (0, utterance_length - mfcc_features.shape[1])),
                               mode='constant', constant_values=0)
        d1_mfcc_feat1 =np.pad(d1_mfcc_feat , ((0, 0), (0, utterance_length - mfcc_features.shape[1])),
                               mode='constant', constant_values=0)
        d2_mfcc_feat1 =np.pad(d2_mfcc_feat , ((0, 0), (0, utterance_length - mfcc_features.shape[1])),
                               mode='constant', constant_values=0)
        
    if mfcc_features1.shape[1] > XP.shape[0]:
         XP1[XP.shape[0]:mfcc_features.shape[1],:]=np.zeros(((mfcc_features.shape[1]-XP.shape[0]),7))

    combined=np.zeros((46,utterance_length))
    combined[:13,] = mfcc_features1
    combined[13:26,]=d1_mfcc_feat1
    combined[26:39,]=d2_mfcc_feat1
    combined[39:46,]=XP1.T
    y[file_no]=int(label)
    train[file_no]=train1
    X[file_no,:]=combined
    file_no=file_no+1
# Out:
# filename------- /content/drive/MyDrive/NEW_MTF/Niram4_train_mtf
niram3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/lokam-niram3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/lokam-niram3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/lokam-niram_mix3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/lokam-niram_mix3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/nallo_niram3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/nallo_niram3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/nirya_niram3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/nirya_niram3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/priyare_niram3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/priyare_niram3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/sahaja_niram3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/sahaja_niram3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/suvinir3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/suvinir3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/tharunir3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/tharunir3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/thathan_niram3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/thathan_niram3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/vathil_niram3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/vathil_niram3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/vigath_niram3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/vigath_niram3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram3_test_mtf/vinjan_niram3
# audio name--- /content/drive/MyDrive/Niram_test/Niram3_test_new/vinjan_niram3.wav
# label-- 2 0
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/Padhavi1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/Padhavi1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/Padhavi1_aug1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/Padhavi1_aug1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/Padhavi1_aug2
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/Padhavi1_aug2.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/Padhavikal_mix1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/Padhavikal_mix1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/Pinvaathil1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/Pinvaathil1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/Pinvaathil_mix1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/Pinvaathil_mix1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/erithi_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/erithi_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/erithi_niram1_aug1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/erithi_niram1_aug1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/erithi_niram1_aug2
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/erithi_niram1_aug2.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/erithi_niram1_aug3
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/erithi_niram1_aug3.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/griha_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/griha_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/kathire11_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/kathire11_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/kathire1_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/kathire1_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/kathire_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/kathire_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/kathire_niram1_aug1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/kathire_niram1_aug1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/mahima11_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/mahima11_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/mahima1_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/mahima1_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/mahima_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/mahima_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/natha_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/natha_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/natha_niram1_aug1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/natha_niram1_aug1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/natha_niram1_aug2
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/natha_niram1_aug2.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/natha_niram_mix1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/natha_niram_mix1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/nathayil_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/nathayil_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/nathayil_niram_mix1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/nathayil_niram_mix1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/raksh1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/raksh1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/sahada_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/sahada_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/shap1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/shap1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/swar_niram1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/swar_niram1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/swar_niram1_aug1
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/swar_niram1_aug1.wav
# label-- 0 1
# filename------- /content/drive/MyDrive/NEW_MTF/Niram1_train_mtf/swar_niram1_aug2
# audio name--- /content/drive/MyDrive/Niram_train/Niram1_train_new/swar_niram1_aug2.wav
# label-- 0 1

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(y)
encoded_Y = encoder.transform(y)
# convert integers to dummy variables (i.e. one hot encoded)
y1 = np_utils.to_categorical(encoded_Y)

# %%
print(y1.shape)
print(X.shape)
input_shape=X.shape[1:]
print(input_shape)
# Out:
# (384, 8)
# (384, 46, 4600)
# (46, 4600)

# %%
X_train, X_test, y_train_n, y_test_n = train_test_split(X, y1, test_size=0.375, random_state=1332, stratify=y1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
sc = StandardScaler()
sc1=MinMaxScaler()

def norml_std(t):
  for i,data in enumerate(t):
    t[i]=sc.fit_transform(data)
  return t 

def norml_minmax(t):
  for i,data in enumerate(t):
    t[i]=sc1.fit_transform(data)
  return t    

from tensorflow.keras.optimizers import SGD
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import LSTM
from keras.layers.recurrent import GRU
from keras.layers.core import Dropout
N_samples=len(X_train)
print(N_samples)
audio_features=46
N_classes=8
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical
import pandas as pd
from sklearn.manifold import TSNE
import seaborn as sn
labels=['Niram1','Niram2','Niram3','Niram4','Niram5','Niram6','Niram7','Niram8']
# Out:
# 240

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(N_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
input_shape = X_train.shape[1:]

# %%
model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

# %%
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["sparse_categorical_accuracy"],
)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 46, 4600)]   0
# __________________________________________________________________________________________________
# layer_normalization_48 (LayerNo (None, 46, 4600)     9200        input_7[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_24 (MultiH (None, 46, 4600)     18849272    layer_normalization_48[0][0]
#                                                                  layer_normalization_48[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 46, 4600)     0           multi_head_attention_24[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_48 (TFOpLa (None, 46, 4600)     0           dropout_54[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_49 (LayerNo (None, 46, 4600)     9200        tf.__operators__.add_48[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 46, 4)        18404       layer_normalization_49[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 46, 4)        0           conv1d_48[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 46, 4600)     23000       dropout_55[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_49 (TFOpLa (None, 46, 4600)     0           conv1d_49[0][0]
#                                                                  tf.__operators__.add_48[0][0]
# __________________________________________________________________________________________________
# layer_normalization_50 (LayerNo (None, 46, 4600)     9200        tf.__operators__.add_49[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_25 (MultiH (None, 46, 4600)     18849272    layer_normalization_50[0][0]
#                                                                  layer_normalization_50[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 46, 4600)     0           multi_head_attention_25[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_50 (TFOpLa (None, 46, 4600)     0           dropout_56[0][0]
#                                                                  tf.__operators__.add_49[0][0]
# __________________________________________________________________________________________________
# layer_normalization_51 (LayerNo (None, 46, 4600)     9200        tf.__operators__.add_50[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 46, 4)        18404       layer_normalization_51[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 46, 4)        0           conv1d_50[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 46, 4600)     23000       dropout_57[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_51 (TFOpLa (None, 46, 4600)     0           conv1d_51[0][0]
#                                                                  tf.__operators__.add_50[0][0]
# __________________________________________________________________________________________________
# layer_normalization_52 (LayerNo (None, 46, 4600)     9200        tf.__operators__.add_51[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_26 (MultiH (None, 46, 4600)     18849272    layer_normalization_52[0][0]
#                                                                  layer_normalization_52[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 46, 4600)     0           multi_head_attention_26[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_52 (TFOpLa (None, 46, 4600)     0           dropout_58[0][0]
#                                                                  tf.__operators__.add_51[0][0]
# __________________________________________________________________________________________________
# layer_normalization_53 (LayerNo (None, 46, 4600)     9200        tf.__operators__.add_52[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 46, 4)        18404       layer_normalization_53[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 46, 4)        0           conv1d_52[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 46, 4600)     23000       dropout_59[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_53 (TFOpLa (None, 46, 4600)     0           conv1d_53[0][0]
#                                                                  tf.__operators__.add_52[0][0]
# __________________________________________________________________________________________________
# layer_normalization_54 (LayerNo (None, 46, 4600)     9200        tf.__operators__.add_53[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_27 (MultiH (None, 46, 4600)     18849272    layer_normalization_54[0][0]
#                                                                  layer_normalization_54[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 46, 4600)     0           multi_head_attention_27[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_54 (TFOpLa (None, 46, 4600)     0           dropout_60[0][0]
#                                                                  tf.__operators__.add_53[0][0]
# __________________________________________________________________________________________________
# layer_normalization_55 (LayerNo (None, 46, 4600)     9200        tf.__operators__.add_54[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 46, 4)        18404       layer_normalization_55[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 46, 4)        0           conv1d_54[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 46, 4600)     23000       dropout_61[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_55 (TFOpLa (None, 46, 4600)     0           conv1d_55[0][0]
#                                                                  tf.__operators__.add_54[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_6 (Glo (None, 46)           0           tf.__operators__.add_55[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          6016        global_average_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 128)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 8)            1032        dropout_62[0][0]
# ==================================================================================================
# Total params: 75,643,352
# Trainable params: 75,643,352
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

# %%
model.fit(
    X_train,
    y_train_n,
    validation_split=0.1,
    epochs=2,
    batch_size=32,
    callbacks= callbacks
)
# Out:
# Epoch 1/2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-fd107ac6a9b4> in <module>()
#       5     epochs=2,
#       6     batch_size=32,
# ----> 7     callbacks= callbacks
#       8 )
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# TypeError: 'NoneType' object is not callable
